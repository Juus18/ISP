# %% [markdown]
# <a href="https://colab.research.google.com/github/Juus18/ISP/blob/main/IDH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import path
import pandas as pd

# %%
idh = pd.read_excel('/content/data (1).xlsx')

# %%
display(idh.describe())
# Out:
#        Posição IDHM       IDHM  Posição IDHM Renda  IDHM Renda  \
# count     27.000000  27.000000           27.000000   27.000000
# mean      13.814815   0.752444           13.962963    0.705815
# std        7.869303   0.036188            7.900737    0.049829
# min        1.000000   0.694000            1.000000    0.621000
# 25%        7.500000   0.724000            7.500000    0.665500
# 50%       14.000000   0.750000           14.000000    0.691000
# 75%       20.000000   0.782500           20.500000    0.739500
# max       27.000000   0.829000           27.000000    0.827000
#
#        Posição IDHM Educação  IDHM Educação  Posição IDHM Longevidade  \
# count              27.000000      27.000000                 27.000000
# mean               13.962963       0.745037                 13.925926
# std                 7.983066       0.044990                  7.932048
# min                 1.000000       0.660000                  1.000000
# ...

# %%
idh.head()
# Out:
#    Territorialidade  Posição IDHM   IDHM  Posição IDHM Renda  IDHM Renda  \
# 0  Distrito Federal             1  0.829                   1       0.827
# 1         São Paulo             2  0.823                   2       0.781
# 2    Santa Catarina             3  0.803                   5       0.763
# 3    Espírito Santo             4  0.792                   9       0.733
# 4      Minas Gerais             5  0.789                  10       0.729
#
#    Posição IDHM Educação  IDHM Educação  Posição IDHM Longevidade  \
# 0                      2          0.825                         6
# 1                      1          0.847                         5
# 2                      4          0.790                         3
# 3                     12          0.758                         1
# 4                      7          0.767                         2
#
#    IDHM Longevidade
# 0             0.836
# 1             0.844
# 2             0.858
# 3             0.895
# 4             0.878
